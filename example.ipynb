# %%
# ==== IMPORTANDO O UTILS ====

import os
import sys

for path in ['src', '../src', '.']:
    if os.path.exists(os.path.join(path, 'utils.py')):
        abs_p = os.path.abspath(path)
        if abs_p not in sys.path:
            sys.path.append(abs_p)
        break

import src.utils as utils

# %%
# ==== CARREGANDO O DATASET ====

dataset = utils.Dataset("data/stage1_train")
print("Carregando dados...")
dataset.get_data()
dataset.split_data()
print("Dados carregados e divididos em treino, validação e teste.")
# Out:
# Carregando dados...
# Split estratificado por modalidade (Total: 670):
#   Treino (468): {np.str_('fluorescence'): 382, np.str_('brightfield_color'): 74, np.str_('brightfield_gray'): 12}
#   Validação (101): {np.str_('fluorescence'): 82, np.str_('brightfield_color'): 16, np.str_('brightfield_gray'): 3}
#   Teste (101): {np.str_('fluorescence'): 82, np.str_('brightfield_color'): 16, np.str_('brightfield_gray'): 3}
# Dados carregados e divididos em treino, validação e teste.

# %%
# ==== TREINANDO E AVALIANDO O MODELO ====

model = utils.Model()
print("Treinando o modelo...")
model.train(dataset)
model.evaluate(dataset)
print("Treinamento e avaliação concluídos.")
# Out:
# Treinando o modelo...
#
# [Fase 1] Backbone CONGELADO | 10 épocas | LR=0.001
#   Epoch [ 1/10] | Train: 0.4076 | Val: 0.4654
#   Epoch [ 2/10] | Train: 0.2715 | Val: 0.2458
#   Epoch [ 3/10] | Train: 0.2126 | Val: 0.1896
#   Epoch [ 4/10] | Train: 0.1776 | Val: 0.1691
#   Epoch [ 5/10] | Train: 0.1549 | Val: 0.1766
#   Epoch [ 6/10] | Train: 0.1415 | Val: 0.1673
#   Epoch [ 7/10] | Train: 0.1320 | Val: 0.1469
#   Epoch [ 8/10] | Train: 0.1252 | Val: 0.1248
#   Epoch [ 9/10] | Train: 0.1199 | Val: 0.1407
#   Epoch [10/10] | Train: 0.1162 | Val: 0.1391
#
# [Fase 2] Backbone DESCONGELADO (fine-tuning) | 10 épocas | LR=0.0001
#   Epoch [ 1/10] | Train: 0.1089 | Val: 0.1132
#   Epoch [ 2/10] | Train: 0.1042 | Val: 0.1103
#   Epoch [ 3/10] | Train: 0.1016 | Val: 0.1114
#   Epoch [ 4/10] | Train: 0.0994 | Val: 0.1089
#   Epoch [ 5/10] | Train: 0.0974 | Val: 0.1090
#   Epoch [ 6/10] | Train: 0.0955 | Val: 0.1074
#   Epoch [ 7/10] | Train: 0.0936 | Val: 0.1105
#   Epoch [ 8/10] | Train: 0.0918 | Val: 0.1087
#   Epoch [ 9/10] | Train: 0.0904 | Val: 0.1103
#   Epoch [10/10] | Train: 0.0890 | Val: 0.1108
#
# Mean Dice: 0.8874 | Mean IoU: 0.8077
#
# Avaliação por Instâncias (Reais (DSB2018))
# Precisão Média (AP) para cada Limiar de IoU (0.50 a 0.95, passo 0.05):
#   IoU = 0.50 : AP = 0.6943
#   IoU = 0.55 : AP = 0.6632
#   IoU = 0.60 : AP = 0.6369
#   IoU = 0.65 : AP = 0.6038
#   IoU = 0.70 : AP = 0.5588
#   IoU = 0.75 : AP = 0.4972
#   IoU = 0.80 : AP = 0.4136
#   IoU = 0.85 : AP = 0.2749
#   IoU = 0.90 : AP = 0.1011
#   IoU = 0.95 : AP = 0.0119
#
# mAP@[.50:.95] Trilha A: 0.4456
# Erro Absoluto Médio de Contagem por Imagem: 8.01 objetos
# Treinamento e avaliação concluídos.
